# %%
import pandas as pd
import numpy as np

# %%
df =  pd.read_csv(r"C:\Users\User\Desktop\bootcamp-fresh\capestone 2\speeddating.csv")

# %%
# Display column names
print("\nColumn Names:\n")
print(df.columns.tolist())

# Display data types
print("\nData Types:\n")
print(df.dtypes)

# Display summary statistics
print("\nSummary Statistics:\n")
print(df.describe())

# Display counts and unique values per column
print("\nUnique Values per Column:\n")
for col in df.columns:
    unique_count = df[col].nunique()
    unique_percent = (unique_count / len(df)) * 100
    print(f"{col}: {unique_count} unique values ({unique_percent:.2f}%)")

# Display range of values for numeric columns
numeric_cols = df.select_dtypes(include=[np.number]).columns
print("\nRange of Numeric Columns:\n")
for col in numeric_cols:
    print(f"{col}: {df[col].min()} - {df[col].max()}")
# Out:
# Column Names:
#
# ...

# %%
# Step 2: Remove Unnecessary Columns
columns_to_drop = ['has_null', 'wave']
df.drop(columns=columns_to_drop, inplace=True)

# %%
# Step 3: Remove 'b''' Format and Convert Data Types
# Function to clean the "b''" prefix and convert to appropriate data types
def clean_b_prefix(val):
    # Check if value is a string and starts with "b'"
    if isinstance(val, str) and val.startswith("b'"):
        return val[2:-1]  # Remove "b'" prefix and trailing "'"
    return val

# Apply the cleaning function to all columns
df = df.applymap(clean_b_prefix)

# Convert numeric columns to numeric data types where applicable
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='ignore')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_38004\1741983660.py:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(clean_b_prefix)
# C:\Users\User\AppData\Local\Temp\ipykernel_38004\1741983660.py:14: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col], errors='ignore')

# %%
# Step 4: Drop Columns Starting with 'd_d_'
d_d_columns = [col for col in df.columns if col.startswith('d_d_')]
df.drop(columns=d_d_columns, inplace=True)

# %%
# Display the first few rows to verify the cleaning process
print("\nData after cleaning:\n")
print(df.head())
# Out:
# Data after cleaning:
#
#    gender   age  age_o  d_age                                   race  \
# 0  female  21.0   27.0    6.0  Asian/Pacific Islander/Asian-American
# 1  female  21.0   22.0    1.0  Asian/Pacific Islander/Asian-American
# 2  female  21.0   22.0    1.0  Asian/Pacific Islander/Asian-American
# 3  female  21.0   23.0    2.0  Asian/Pacific Islander/Asian-American
# 4  female  21.0   24.0    3.0  Asian/Pacific Islander/Asian-American
#
#                                   race_o  samerace  importance_same_race  \
# 0            European/Caucasian-American         0                   2.0
# 1            European/Caucasian-American         0                   2.0
# 2  Asian/Pacific Islander/Asian-American         1                   2.0
# 3            European/Caucasian-American         0                   2.0
# 4               Latino/Hispanic American         0                   2.0
#
#    importance_same_religion d_importance_same_race  ...  \
# ...

# %%
df.to_csv('cleaned_speeddating.csv', index=False)
